# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
def plot_roc_curve(fper, tper):
    plt.figure()
    plt.plot(fper, tper, color='red', label="ROC curve (area = %0.2f)" % auc(fper,tper))
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend()
    plt.show()

# %%
df1=pd.read_csv('/home/NAS_mount/yslee/dataset/score/crossval1_F1model_score.csv')
df2=pd.read_csv('/home/NAS_mount/yslee/dataset/score/crossval2_F1model_score.csv')
df3=pd.read_csv('/home/NAS_mount/yslee/dataset/score/crossval3_F1model_score.csv')
df4=pd.read_csv('/home/NAS_mount/yslee/dataset/score/crossval4_ACCF1model_score.csv')
df5=pd.read_csv('/home/NAS_mount/yslee/dataset/score/crossval5_ACCF1model_score.csv')

fpr1,tpr1,_=roc_curve(df1['label'],df1['fail_score'])
fpr2,tpr2,_=roc_curve(df2['label'],df2['fail_score'])
fpr3,tpr3,_=roc_curve(df3['label'],df3['fail_score'])
fpr4,tpr4,_=roc_curve(df4['label'],df4['fail_score'])
fpr5,tpr5,_=roc_curve(df5['label'],df5['fail_score'])

# %%
vgg_df1=pd.read_csv('/home/NAS_mount/yslee/dataset/score/vgg_crossval1_ACCmodel_score.csv')
vgg_df2=pd.read_csv('/home/NAS_mount/yslee/dataset/score/vgg_crossval2_ACCF1model_later_score.csv')

vgg_fpr1,vgg_tpr1,_=roc_curve(vgg_df1['label'],vgg_df1['fail_score'])
vgg_fpr2,vgg_tpr2,_=roc_curve(vgg_df2['label'],vgg_df2['fail_score'])

# %%
resnet_df1=pd.read_csv('/home/NAS_mount/yslee/dataset/score/resnet_crossval1_ACCmodel_score2.csv')
resnet_df2=pd.read_csv('/home/NAS_mount/yslee/dataset/score/resnet_crossval2_ACCF1model_score.csv')
resnet_df3=pd.read_csv('/home/NAS_mount/yslee/dataset/score/resnet_crossval3_F1model_score.csv')
resnet_df4=pd.read_csv('/home/NAS_mount/yslee/dataset/score/resnet_crossval4_ACCF1model_score.csv')
resnet_df5=pd.read_csv('/home/NAS_mount/yslee/dataset/score/resnet_crossval5_ACCF1model_score.csv')

resnet_fpr1,resnet_tpr1,_=roc_curve(resnet_df1['label'],resnet_df1['fail_score'])
resnet_fpr2,resnet_tpr2,_=roc_curve(resnet_df2['label'],resnet_df2['fail_score'])
resnet_fpr3,resnet_tpr3,_=roc_curve(resnet_df3['label'],resnet_df3['fail_score'])
resnet_fpr4,resnet_tpr4,_=roc_curve(resnet_df4['label'],resnet_df4['fail_score'])
resnet_fpr5,resnet_tpr5,_=roc_curve(resnet_df5['label'],resnet_df5['fail_score'])

# %%
clinical_df=pd.read_csv('/home/NAS_mount/yslee/dataset/score/clinical_model_score4.csv')

# %%
clinical_fpr,clinical_tpr,_=roc_curve(clinical_df['label'],clinical_df['fail_score'])

# %%
plot_roc_curve(clinical_fpr,clinical_tpr)

# %%
plt.figure()
plt.plot(fpr1, tpr1, color='red', label="fold1 (area = %0.2f)" % auc(fpr1,tpr1))
plt.plot(fpr2, tpr2, color='darkorange', label="fold2 (area = %0.2f)" % auc(fpr2,tpr2))
plt.plot(fpr3, tpr3, color='aqua', label="fold3 (area = %0.2f)" % auc(fpr3,tpr3))
plt.plot(fpr4, tpr4, color='green', label="fold4 (area = %0.2f)" % auc(fpr4,tpr4))
plt.plot(fpr5, tpr5, color='purple', label="fold5 (area = %0.2f)" % auc(fpr5,tpr5))
plt.plot([0, 1], [0, 1], color='black', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AttenNet ROC Curve')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(vgg_fpr1, vgg_tpr1, color='red', label="fold1 (area = %0.2f)" % auc(vgg_fpr1,vgg_tpr1))
plt.plot(vgg_fpr2, vgg_tpr2, color='darkorange', label="fold2 (area = %0.2f)" % auc(vgg_fpr2,vgg_tpr2))
plt.plot([0, 1], [0, 1], color='black', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('VGG ROC Curve')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(resnet_fpr1, resnet_tpr1, color='red', label="fold1 (area = %0.2f)" % auc(resnet_fpr1,resnet_tpr1))
plt.plot(resnet_fpr2, resnet_tpr2, color='darkorange', label="fold2 (area = %0.2f)" % auc(resnet_fpr2,resnet_tpr2))
plt.plot(resnet_fpr3, resnet_tpr3, color='aqua', label="fold3 (area = %0.2f)" % auc(resnet_fpr3,resnet_tpr3))
plt.plot(resnet_fpr4, resnet_tpr4, color='green', label="fold4 (area = %0.2f)" % auc(resnet_fpr4,resnet_tpr4))
plt.plot(resnet_fpr5, resnet_tpr5, color='purple', label="fold5 (area = %0.2f)" % auc(resnet_fpr5,resnet_tpr5))
plt.plot([0, 1], [0, 1], color='black', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ResNet ROC Curve')
plt.legend()
plt.show()

# %%
import os
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from training_modules import train_model,test_model,test_model2,get_clinical_features,train_3model2
from dental_datasets import DentalDataset
from torch import optim
from torch.optim import lr_scheduler
from datetime import datetime
import pandas as pd
from Attention_ResNet import Ensemble, Net, Net2,ClinicalModel, ResNet18
import numpy as np
import pandas as pd

split_path='/home/NAS_mount/yslee/dataset/crossval_dataset3-1103flip'
train_path=os.path.join(split_path,'train')
val_path=os.path.join(split_path,'val')
test_path=os.path.join(split_path,'test')

org_dic = np.load('/home/NAS_mount/yslee/dataset/org_dic_1101.npy',allow_pickle='TRUE').item()

label_file=pd.read_csv('/home/NAS_mount/yslee/dataset/premolar_labels_0810.csv')
label_file=label_file.set_index('PatientID_new')
label_file=label_file['Result']

preprocessed_mean=0.59
preprocessed_std=0.24
org_mean=0.70
org_std=0.20

data_normalization={'preprocessed': transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((preprocessed_mean,), (preprocessed_std,))
]),
    'original': transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((org_mean,), (org_std,))
])        
}

dataset={'train': DentalDataset(preprocessed_dir=train_path,org_dic=org_dic,label_file=label_file,normalize=data_normalization,augmentation=True,grad_dic=None,grad_dic2=None),
            'val': DentalDataset(preprocessed_dir=val_path,org_dic=org_dic,label_file=label_file,normalize=data_normalization,augmentation=False,grad_dic=None,grad_dic2=None),
            'test': DentalDataset(preprocessed_dir=test_path,org_dic=org_dic,label_file=label_file,normalize=data_normalization,augmentation=False,grad_dic=None,grad_dic2=None)}

dataloaders={'train': torch.utils.data.DataLoader(dataset['train'],batch_size=15,shuffle=True),
                'val':torch.utils.data.DataLoader(dataset['val'],batch_size=15,shuffle=True),
                'test':torch.utils.data.DataLoader(dataset['test'],batch_size=15,shuffle=False)}

dataset_sizes = {'train': dataset['train'].__len__(),
                    'val':dataset['val'].__len__(),
                    'test':dataset['test'].__len__()}

# %%
from sklearn.metrics import confusion_matrix
import torch.nn.functional as F

def test_score(model,dataloaders,device):
    CM=0

    model.eval()
    score_df=pd.DataFrame()
    with torch.no_grad():
        for data in dataloaders['test']:
            images, labels, file_name = data
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images) #file_name
            preds = torch.argmax(outputs.data, 1)
            
            filename_df=pd.DataFrame(file_name)
            outputs_df=pd.DataFrame(np.array(F.softmax(outputs)))
            preds_df=pd.DataFrame(preds)
            labels_df=pd.DataFrame(labels)
            
            concat_df=pd.concat([filename_df,outputs_df,preds_df,labels_df],axis=1)

            CM+=confusion_matrix(labels.cpu(), preds.cpu(),labels=[0,1])
            score_df=pd.concat([score_df,concat_df],axis=0)
            
        tn=CM[0][0]
        tp=CM[1][1]
        fp=CM[0][1]
        fn=CM[1][0]

        acc=np.sum(np.diag(CM)/np.sum(CM))
        
        print('\nTestset Accuracy(mean): %f %%' % (100 * acc))
        print()
        print('Confusion Matirx : ')
        print(CM)
        print('- Sensitivity : ',(tp/(tp+fn))*100)
        print('- Specificity : ',(tn/(tn+fp))*100)
        print()

        score_df.columns=['PatientID','success_score','fail_score','prediction','label']
    return score_df

# %%
device_cpu=torch.device('cpu')

model=Net()
'''model=torchvision.models.resnet18(pretrained=False)
model.conv1=nn.Conv2d(2, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
model.fc=nn.Linear(in_features=512, out_features=2, bias=True)'''

model.load_state_dict(torch.load('/home/NAS_mount/yslee/dataset/models/1103/f1crossval3_11-03-13:56.pt', map_location={"cuda" : "cpu"}))
model=model.to(device_cpu)
model.eval()

Net17_score=test_score(model,dataloaders,device_cpu)
# Out:
# /home/yslee/tmp/conda/envs/cuda_env/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Testset Accuracy(mean): 65.000000 %
#
# Confusion Matirx :
# [[52 18]
#  [17 13]]
# - Sensitivity :  43.333333333333336
# - Specificity :  74.28571428571429

# %%
df0=pd.read_csv('/home/NAS_mount/yslee/dataset/score/ACCF1attenetwithCAM_score.csv')
fpr0,tpr0,_=roc_curve(df0['label'],df0['fail_score'])
plot_roc_curve(fpr0,tpr0)

# %%
Net17_score.to_csv('/home/NAS_mount/yslee/dataset/score/resnet_crossval1_ACCmodel_score2.csv',index=False)
